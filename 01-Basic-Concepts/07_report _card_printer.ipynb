# %% [markdown]
# # Project 07: Build a Report Card Printer In this workshop, I am practicing **String Formatting** in Python to create a clean, readable report card layout.

# %% [markdown]
# ## **Step 1**
# ## Create a variable called **name** and assign it the string **Alice**. Remember to surround the value with either single or double quotes as shown in the example.

# %%
name = "Alice"

# %% [markdown]
# ##

# %% [markdown]
# ## **step 2**
# ## print the **name** variable. Check the output in the terminal.

# %%
name = 'Alice'
print(name)
# Out:
# Alice

# %% [markdown]
# ## **step 3**
# ## Use the **type()** function with **name** as its argument and print the output

# %%
name = 'Alice'
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## **step 4**
# ## Declare a variable named **is_student** and assign it the value **True**.

# %%
name = 'Alice'
print(name)
print(type(name))

is_student = True
# Out:
# Alice
# <class 'str'>

# %% [markdown]
# ## **step 5**
# ## Print both **is_student** and **type(is_student)** on the same line using a comma , as shown in the example. Then, check the output in the terminal that shows the value of is_student, and its tpe yas bool (boolean).

# %%
name = 'Alice'
print(name)
print(type(name))

is_student = True
print (is_student ,type(is_student))
# Out:
# Alice
# <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ## **step 6**
# ## Remove the earlier outputs of the **name** variable. Then, print **name** and **type(name)** together on one line separated by a comma like the previous step.

# %%
name = 'Alice'
print(name,type(name))

is_student = True
print(is_student, type(is_student))
# Out:
# Alice <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ## **step 7**
# ## Declare a variable named **age** and assign it the integer value **20**.Then, print the value and data type of age together separated by a comma. Check the output in the terminal that shows the value of age, and its type as int (integer).

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age ,type(age))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>

# %% [markdown]
# ## **step 8**
# ## Declare a variable named **score** and assign it the value **80.5**.Use **isinstance()** to check whether **score** is an **int**, and print the result to the terminal as shown in the example above.

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print (isinstance(score,int))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# False

# %% [markdown]
# ## **step 9 The final code**
# ## Replace **int** with **float** in the existing **isinstance()** call to confirm this.Finally, print **score** and its data type to complete the report card.

# %% [markdown]
# ##

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, float))
print (score,type(score))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# True
# 80.5 <class 'float'>
